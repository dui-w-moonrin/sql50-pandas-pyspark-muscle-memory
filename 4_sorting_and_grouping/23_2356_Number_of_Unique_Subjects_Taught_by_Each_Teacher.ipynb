# %% [markdown]
# # 0. Problem
# ## 2356. Number of Unique Subjects Taught by Each Teacher — Easy
# Count distinct `subject_id` per teacher as `cnt`.
# Official: https://leetcode.com/problems/number-of-unique-subjects-taught-by-each-teacher/

# %% [markdown]
# # 1. Setup

# %%
import pandas as pd
teacher_rows=[(1,2,3),(1,2,4),(1,3,3),(2,1,1),(2,2,1),(2,3,1),(2,4,1)]
teacher_pd=pd.DataFrame(teacher_rows,columns=["teacher_id","subject_id","dept_id"])
teacher_pd

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
spark=SparkSession.builder.getOrCreate()
teacher_spark=spark.createDataFrame(teacher_rows,["teacher_id","subject_id","dept_id"])
teacher_spark.createOrReplaceTempView("Teacher")

# %% [markdown]
# # 2. SQL Solution

# %%
sql_result=spark.sql("""SELECT teacher_id,COUNT(DISTINCT subject_id) AS cnt FROM Teacher GROUP BY teacher_id""")
sql_result.show(truncate=False)

# %% [markdown]
# # 3. pandas Solution

# %%
result_pd=teacher_pd.groupby("teacher_id",as_index=False).agg(cnt=("subject_id","nunique"))
result_pd

# %% [markdown]
# # 4. PySpark Solution

# %%
result_spark=teacher_spark.groupBy("teacher_id").agg(F.countDistinct("subject_id").alias("cnt"))
result_spark.show(truncate=False)

# %% [markdown]
# # 5. Pattern Mapping
# | Concept | SQL | pandas | PySpark |
# |---|---|---|---|
# | distinct count | `COUNT(DISTINCT ...)` | `nunique` | `F.countDistinct()` |
# | group | `GROUP BY` | `.groupby()` | `.groupBy()` |

# %% [markdown]
# # 6. Muscle-Memory Round
#
# พิมพ์ใหม่เองโดยไม่ copy คำตอบด้านบน

# %%
# MUSCLE MEMORY — SQL
# Rebuild using temp view(s): Teacher

# %%
# MUSCLE MEMORY — PANDAS
# Rebuild using: teacher_pd

# %%
# MUSCLE MEMORY — PYSPARK
# Rebuild using: teacher_spark

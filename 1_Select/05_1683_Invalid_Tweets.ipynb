# %% [markdown]
# # 1683. Invalid Tweets
#
# [LeetCode problem](https://leetcode.com/problems/invalid-tweets/)

# %% [markdown]
# # 0. Problem
#
# A tweet is invalid when content has more than 15 characters. Return invalid `tweet_id` values.

# %% [markdown]
# # 1. Setup

# %%
import pandas as pd
tweet_rows=[(1,'Vote for Biden'),(2,'Let us make America great again!'),(3,'short message'),(4,'1234567890123456')]
tweet_pd=pd.DataFrame(tweet_rows,columns=['tweet_id','content'])

# %%
# In Colab if needed: !pip -q install pyspark
from pyspark.sql import SparkSession, functions as F, types as T
spark=SparkSession.builder.getOrCreate()
schema=T.StructType([T.StructField('tweet_id',T.IntegerType(),False),T.StructField('content',T.StringType(),False)])
tweet_spark=spark.createDataFrame(tweet_rows,schema)
tweet_spark.createOrReplaceTempView('Tweets')

# %% [markdown]
# # 2. SQL Solution

# %%
sql_result=spark.sql("""SELECT tweet_id FROM Tweets WHERE LENGTH(content)>15""")
sql_result.show(truncate=False)

# %% [markdown]
# # 3. pandas Solution

# %%
pandas_result=tweet_pd.loc[tweet_pd['content'].str.len()>15,['tweet_id']]
pandas_result

# %% [markdown]
# # 4. PySpark Solution

# %%
spark_result=tweet_spark.filter(F.length('content')>15).select('tweet_id')
spark_result.show(truncate=False)

# %% [markdown]
# # 5. Pattern Mapping
#
# | Concept | SQL | pandas | PySpark |
# |---|---|---|---|
# | string length | `LENGTH()` | `.str.len()` | `F.length()` |
# | filter | `WHERE` | boolean mask | `.filter()` |

# %% [markdown]
# # 6. Muscle-Memory Round

# %%
# MUSCLE MEMORY — SQL
# Use temp view: Tweets

# %%
# MUSCLE MEMORY — PANDAS
# Use DataFrame: tweet_pd

# %%
# MUSCLE MEMORY — PYSPARK
# Use DataFrame: tweet_spark
